# %%
# import pandas
import pandas as pd

# %%
# read csv 
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Adding a New Column

# %% [markdown]
# ### 1.1 assign()

# %% [markdown]
# When to use assign?
# * Add multiple columns in a single line of code
# * When you need to overwrite the values of an existing columns (best practice)

# %% [markdown]
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# create random numbers for our new scores
score1 = np.random.randint(1,100,size=1000)
score2 = np.random.randint(1,100,size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))

# %%
# assigning the series using the assigne() method
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
# show the DataFrame
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      83
# 1                 completed          69             90             88      11
# 2                      none          90             95             93      19
# 3                      none          47             57             44      15
# 4                      none          76             78             75      18
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      13
# 996                    none          62             55             55      76
# 997               completed          59             71             65      34
# 998               completed          68             78             77      38
# 999                    none          77             86             86      73
#
#      score2
# 0        59
# 1        21
# 2        65
# 3        91
# 4        44
# ..      ...
# 995      73
# 996      71
# 997      40
# 998      43
# 999      94
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### 1.2 Insert()

# %% [markdown]
# Inserts a new column to a specific position or index.

# %%
# using index() to a new column at a specific position
df_exams.insert(1, 'test', series1)

# %%
# show the DataFrame
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    83        group B           bachelor's degree      standard
# 1    female    11        group C                some college      standard
# 2    female    19        group B             master's degree      standard
# 3      male    15        group A          associate's degree  free/reduced
# 4      male    18        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    13        group E             master's degree      standard
# 996    male    76        group C                 high school  free/reduced
# 997  female    34        group C                 high school  free/reduced
# 998  female    38        group D                some college      standard
# 999  female    73        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      83
# 1                 completed          69             90             88      11
# 2                      none          90             95             93      19
# 3                      none          47             57             44      15
# 4                      none          76             78             75      18
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      13
# 996                    none          62             55             55      76
# 997               completed          59             71             65      34
# 998               completed          68             78             77      38
# 999                    none          77             86             86      73
#
#      score2
# 0        59
# 1        21
# 2        65
# 3        91
# 4        44
# ..      ...
# 995      73
# 996      71
# 997      40
# 998      43
# 999      94
#
# [1000 rows x 11 columns]
