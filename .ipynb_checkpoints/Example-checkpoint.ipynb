# %% [markdown]
# # Title

# %% [markdown]
# * this is a bullet point

# %% [markdown]
# **this a Bold text**

# %% [markdown]
# `this is a code format`

# %% [markdown]
# ## Subtitle

# %%
"hi World!"
# Out:
# 'hi World!'
