# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\rahul\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rahul\AppData\Local\Temp\ipykernel_17920\3667953147.py", line 1, in <module>
#     df_laptops = pd.read_csv('laptop_price.csv')
#   File "C:\Users\rahul\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\rahul\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "C:\Users\rahul\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
# ...
